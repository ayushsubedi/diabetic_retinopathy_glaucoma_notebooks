# %% [markdown]
# ### TODO
#
# - balance imbalanced class better
# -

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
import os
from PIL import Image as PILImage
# %matplotlib inline
from IPython.display import display, Image
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../datasets/trainLabels.csv")

# %%
list(df)
# Out:
# ['image', 'level']

# %%
df.head()
# Out:
#       image  level
# 0   10_left      0
# 1  10_right      0
# 2   13_left      0
# 3  13_right      0
# 4   15_left      1

# %%
df['patient_id'] = df.image.map(lambda x:x.split('_')[0])
df['eye'] = df.image.map(lambda x:x.split('_')[1])
df['local_file_path'] = df.image.map(lambda x:"../datasets/resized_train/"+x+".jpeg")

# %%
df
# Out:
#              image  level patient_id    eye  \
# 0          10_left      0         10   left
# 1         10_right      0         10  right
# 2          13_left      0         13   left
# 3         13_right      0         13  right
# 4          15_left      1         15   left
# ...            ...    ...        ...    ...
# 35121  44347_right      0      44347  right
# 35122   44348_left      0      44348   left
# 35123  44348_right      0      44348  right
# 35124   44349_left      0      44349   left
# 35125  44349_right      1      44349  right
#
#                                   local_file_path
# 0          ../datasets/resized_train/10_left.jpeg
# 1         ../datasets/resized_train/10_right.jpeg
# 2          ../datasets/resized_train/13_left.jpeg
# 3         ../datasets/resized_train/13_right.jpeg
# 4          ../datasets/resized_train/15_left.jpeg
# ...                                           ...
# 35121  ../datasets/resized_train/44347_right.jpeg
# 35122   ../datasets/resized_train/44348_left.jpeg
# 35123  ../datasets/resized_train/44348_right.jpeg
# 35124   ../datasets/resized_train/44349_left.jpeg
# 35125  ../datasets/resized_train/44349_right.jpeg
#
# [35126 rows x 5 columns]

# %%
df['file_exists'] = df.local_file_path.map(lambda x:os.path.exists(x))

# %%
df
# Out:
#              image  level patient_id    eye  \
# 0          10_left      0         10   left
# 1         10_right      0         10  right
# 2          13_left      0         13   left
# 3         13_right      0         13  right
# 4          15_left      1         15   left
# ...            ...    ...        ...    ...
# 35121  44347_right      0      44347  right
# 35122   44348_left      0      44348   left
# 35123  44348_right      0      44348  right
# 35124   44349_left      0      44349   left
# 35125  44349_right      1      44349  right
#
#                                   local_file_path  file_exists
# 0          ../datasets/resized_train/10_left.jpeg         True
# 1         ../datasets/resized_train/10_right.jpeg         True
# 2          ../datasets/resized_train/13_left.jpeg         True
# 3         ../datasets/resized_train/13_right.jpeg         True
# 4          ../datasets/resized_train/15_left.jpeg         True
# ...                                           ...          ...
# 35121  ../datasets/resized_train/44347_right.jpeg         True
# 35122   ../datasets/resized_train/44348_left.jpeg         True
# 35123  ../datasets/resized_train/44348_right.jpeg         True
# 35124   ../datasets/resized_train/44349_left.jpeg         True
# 35125  ../datasets/resized_train/44349_right.jpeg         True
#
# [35126 rows x 6 columns]

# %%
display(Image("../datasets/resized_train/10_left.jpeg"))

# %%
df
# Out:
#              image  level patient_id    eye  \
# 0          10_left      0         10   left
# 1         10_right      0         10  right
# 2          13_left      0         13   left
# 3         13_right      0         13  right
# 4          15_left      1         15   left
# ...            ...    ...        ...    ...
# 35121  44347_right      0      44347  right
# 35122   44348_left      0      44348   left
# 35123  44348_right      0      44348  right
# 35124   44349_left      0      44349   left
# 35125  44349_right      1      44349  right
#
#                                   local_file_path  file_exists
# 0          ../datasets/resized_train/10_left.jpeg         True
# 1         ../datasets/resized_train/10_right.jpeg         True
# 2          ../datasets/resized_train/13_left.jpeg         True
# 3         ../datasets/resized_train/13_right.jpeg         True
# 4          ../datasets/resized_train/15_left.jpeg         True
# ...                                           ...          ...
# 35121  ../datasets/resized_train/44347_right.jpeg         True
# 35122   ../datasets/resized_train/44348_left.jpeg         True
# 35123  ../datasets/resized_train/44348_right.jpeg         True
# 35124   ../datasets/resized_train/44349_left.jpeg         True
# 35125  ../datasets/resized_train/44349_right.jpeg         True
#
# [35126 rows x 6 columns]

# %%
df.level.value_counts()
# Out:
# 0    25810
# 2     5292
# 1     2443
# 3      873
# 4      708
# Name: level, dtype: int64

# %%
df.level.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#              image  level patient_id    eye  \
# 0          10_left      0         10   left
# 1         10_right      0         10  right
# 2          13_left      0         13   left
# 3         13_right      0         13  right
# 4          15_left      1         15   left
# ...            ...    ...        ...    ...
# 35121  44347_right      0      44347  right
# 35122   44348_left      0      44348   left
# 35123  44348_right      0      44348  right
# 35124   44349_left      0      44349   left
# 35125  44349_right      1      44349  right
#
#                                   local_file_path  file_exists
# 0          ../datasets/resized_train/10_left.jpeg         True
# 1         ../datasets/resized_train/10_right.jpeg         True
# 2          ../datasets/resized_train/13_left.jpeg         True
# 3         ../datasets/resized_train/13_right.jpeg         True
# 4          ../datasets/resized_train/15_left.jpeg         True
# ...                                           ...          ...
# 35121  ../datasets/resized_train/44347_right.jpeg         True
# 35122   ../datasets/resized_train/44348_left.jpeg         True
# 35123  ../datasets/resized_train/44348_right.jpeg         True
# 35124   ../datasets/resized_train/44349_left.jpeg         True
# 35125  ../datasets/resized_train/44349_right.jpeg         True
#
# [35126 rows x 6 columns]

# %%
df[['image', 'level']].drop_duplicates()
# Out:
#              image  level
# 0          10_left      0
# 1         10_right      0
# 2          13_left      0
# 3         13_right      0
# 4          15_left      1
# ...            ...    ...
# 35121  44347_right      0
# 35122   44348_left      0
# 35123  44348_right      0
# 35124   44349_left      0
# 35125  44349_right      1
#
# [35126 rows x 2 columns]

# %% [markdown]
# ### Just stratifying to get around the issue of imbalanced classes

# %%
SEED=42
train_x, valid_x, train_y, valid_y = train_test_split(df.drop('level', axis=1), df.level, test_size=0.20,
                                                      stratify=df.level, random_state=SEED)

# %%
train_x.shape, valid_x.shape, train_y.shape, valid_y.shape
# Out:
# ((28100, 5), (7026, 5), (28100,), (7026,))
