# %% [markdown]
# ## Mount Google Drive

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Get API key from kaggle
# - go to your profile in settings
# - get api key, store it locally

# %% [markdown]
# Upload it using the cell below

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-8f3d335c-db3d-4cfc-8415-af63a7ff394e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f3d335c-db3d-4cfc-8415-af63a7ff394e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"ayushsubedi","key":"3e35ef7e4ca7d5ebb110014575a431f4"}'}

# %%
# !ls -lha kaggle.json
# Out:
# -rw-r--r-- 1 root root 67 Mar 18 10:22 kaggle.json

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !pwd
# Out:
# /content

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              216KB  2021-03-18 08:52:01            545
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   1GB  2021-02-18 10:08:27            483
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-02-17 16:10:44            420
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19            190
# ...

# %%
# !kaggle competitions download -c aptos2019-blindness-detection -p aptos
# !kaggle datasets download benjaminwarner/resized-2015-2019-blindness-detection-images
# Out:
# ...
# 100% 17.3G/17.3G [04:50<00:00, 54.1MB/s]
# 100% 17.3G/17.3G [04:50<00:00, 64.1MB/s]

# %%
# !unzip /content/resized-2015-2019-blindness-detection-images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: resized train 15/8514_left.jpg
#   inflating: resized train 15/8514_right.jpg
#   inflating: resized train 15/8515_left.jpg
#   inflating: resized train 15/8515_right.jpg
#   inflating: resized train 15/8517_left.jpg
#   inflating: resized train 15/8517_right.jpg
#   inflating: resized train 15/8519_left.jpg
#   inflating: resized train 15/8519_right.jpg
#   inflating: resized train 15/851_left.jpg
#   inflating: resized train 15/851_right.jpg
#   inflating: resized train 15/8522_left.jpg
#   inflating: resized train 15/8522_right.jpg
#   inflating: resized train 15/8526_left.jpg
#   inflating: resized train 15/8526_right.jpg
#   inflating: resized train 15/8527_left.jpg
#   inflating: resized train 15/8527_right.jpg
#   inflating: resized train 15/8531_left.jpg
#   inflating: resized train 15/8531_right.jpg
#   inflating: resized train 15/8532_left.jpg
#   inflating: resized train 15/8532_right.jpg
# ...

# %%
pd.read_csv('labels/trainLabels15.csv')
# Out:
#              image  level
# 0          10_left      0
# 1         10_right      0
# 2          13_left      0
# 3         13_right      0
# 4          15_left      1
# ...            ...    ...
# 35121  44347_right      0
# 35122   44348_left      0
# 35123  44348_right      0
# 35124   44349_left      0
# 35125  44349_right      1
#
# [35126 rows x 2 columns]

# %%
pd.read_csv('labels/testLabels15.csv')
# Out:
#              image  level    Usage
# 0           1_left      0  Private
# 1          1_right      0  Private
# 2           2_left      0   Public
# 3          2_right      0   Public
# 4           3_left      2  Private
# ...            ...    ...      ...
# 53571  44346_right      0  Private
# 53572   44350_left      0  Private
# 53573  44350_right      0  Private
# 53574   44351_left      0   Public
# 53575  44351_right      0   Public
#
# [53576 rows x 3 columns]

# %%
pd.read_csv('labels/testImages19.csv')
# Out:
#            id_code
# 0     0005cfc8afb6
# 1     003f0afdcd15
# 2     006efc72b638
# 3     00836aaacf06
# 4     009245722fa4
# ...            ...
# 1923  ff2fd94448de
# 1924  ff4c945d9b17
# 1925  ff64897ac0d8
# 1926  ffa73465b705
# 1927  ffdc2152d455
#
# [1928 rows x 1 columns]

# %%
pd.read_csv('labels/trainLabels19.csv')
# Out:
#            id_code  diagnosis
# 0     000c1434d8d7          2
# 1     001639a390f0          4
# 2     0024cdab0c1e          1
# 3     002c21358ce6          0
# 4     005b95c28852          0
# ...            ...        ...
# 3657  ffa47f6a7bf4          2
# 3658  ffc04fed30e6          0
# 3659  ffcf7b45f213          2
# 3660  ffd97f8cd5aa          0
# 3661  ffec9a18a3ce          2
#
# [3662 rows x 2 columns]
